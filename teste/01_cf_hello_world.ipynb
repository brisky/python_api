# %% [markdown]
# # Hello World
#
# * author: __César Freire__
# * date: __2023-12-06__
#
# ## Useful links
#
# * Jupyter: https://jupyter.org/
# * Markdown: https://www.markdownguide.org/

# %%
# code cell
print('hello world!')
# Out:
# hello world!

# %% [markdown]
# ## Simple plot

# %%
#%%writefile plot_example.py
import numpy as np
from matplotlib import pyplot as plt

array = np.random.rand(100)
plt.plot(array)
plt.show()
